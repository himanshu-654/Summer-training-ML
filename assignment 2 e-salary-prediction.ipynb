# %%
#importing libraries
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../input/esalary/e- salary.csv')

# %%
data.head()

# %%
data.shape

# %%
plt.hist(data.Salary,color='Red')
plt.show()

# %%
target =np.log(data.Salary)
plt.hist(target,color='Blue')
plt.show()

# %%
numeric_features=data.select_dtypes(include=[np.number])
numeric_features.dtypes

# %%
corr=numeric_features.corr()
print(corr['Salary'].sort_values(ascending=False)[:5],'\n')
print(corr['Salary'].sort_values(ascending=False)[-5:],'\n')

# %%
quality_pivot=data.pivot_table(index='employes name',values='Salary', aggfunc=np.median)
quality_pivot.plot(kind='bar', color='blue')

plt.xlabel('Overall Quality')
plt.xlabel('Median Sale Price')
plt.xticks(rotation=0)
plt.show()

# %%
plt.scatter(x=data['employes name'], y=np.log(data['Salary']))
plt.ylabel('Salary')
plt.xlabel('Above Grade Living area square feet')

plt.show()

# %%
plt.scatter(x=data['employes name'], y=np.log(data['Salary']))
plt.ylabel('Salary')
plt.xlabel('empoyes name')

plt.show()

# %%
data=data[data['employes name']< 500000 ]
plt.scatter(x=data['employes name'], y=np.log(data.Salary))
plt.xlim(37000,46000)
plt.ylabel('Salary')
plt.xlabel('employes name')

plt.show()

# %%
nulls=pd.DataFrame(data.isnull().sum().sort_values(ascending=False)[:25])
nulls.columns=['Null Count']
nulls.index.name='Feature'
nulls

# %%
categoricals=data.select_dtypes(exclude=[np.number])

categoricals.describe()

# %%
data['enc_salary']=pd.get_dummies(data.Salary,drop_first=True)
print('Encoded:\n')
print(data.enc_salary.value_counts())

# %%
data= data.select_dtypes(include=[np.number]).interpolate().dropna()

sum(data.isnull().sum()!=0)

# %%
y=np.log(data.Salary)
X=data.drop(['Salary', 'employes name'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.8, random_state=44, shuffle =True)

# %%
from sklearn.linear_model import LinearRegression

LinearRegressionModel = LinearRegression()
LinearRegressionModel.fit(X_train, y_train)
print('Linear Regression Train Score is : ' , LinearRegressionModel.score(X_train, y_train))
print('Linear Regression Test Score is : ' , LinearRegressionModel.score(X_test, y_test))
print('Linear Regression Coef is : ' , LinearRegressionModel.coef_)
print('Linear Regression intercept is : ' , LinearRegressionModel.intercept_)

# %%
y_pred_linear = LinearRegressionModel.predict(X_test)
print('Y predict: ',y_pred_linear[:5])
print('Y test: ', y_test[:5])

# %%
from sklearn.metrics import mean_squared_error
print('root square error is',LinearRegressionModel.score(X_test, y_test))
predictions=LinearRegressionModel.predict(X_test)

print('RMSE', mean_squared_error(y_test, predictions))

# %%
actual_values=data
plt.scatter(predictions, actual_values,alpha=.7, color='b')
plt.xlabel('Predicted Price')
plt.ylabel('Actual Price')
plt.title('Linear Regression Model')

plt.show()
